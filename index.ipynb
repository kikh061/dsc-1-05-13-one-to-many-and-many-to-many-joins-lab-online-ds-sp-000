# %% [markdown]
# # One-to-Many and Many-to-Many Joins - Lab

# %% [markdown]
# ## Introduction

# %% [markdown]
# In this lab, you'll practice your knowledge on One-to-Many and Many-to-many relationships!

# %% [markdown]
# ## Objectives

# %% [markdown]
# You will be able to:
# - Query data including Many-to-Many relationships
# - Write queries that make use of Join Tables

# %% [markdown]
# ## One-to-Many and Many-to-Many Joins
# <img src='Database-Schema.png' width=550>

# %%
import sqlite3
import pandas as pd

conn = sqlite3.connect('data.sqlite',detect_types=sqlite3.PARSE_COLNAMES)
cur = conn.cursor()

# %% [markdown]
# ## Employees and their Office (a One-to-One join)
#
# Return a list of all of the employees with their first name, last name and the city and state of the office that they work out of (if they have one). Include all employees and order them by their first name, then their last name.

# %%
cur.execute('''select firstName, lastName, city, state
                from employees e
                join offices o on e.officeCode = o.officeCode
                order by firstName, lastName
                ''')
df = pd.DataFrame(cur.fetchall())
df.columns = [i[0]for i in cur.description]
df.head()
# Out:
#   firstName lastName           city state
# 0      Andy   Fixter         Sydney
# 1   Anthony      Bow  San Francisco    CA
# 2     Barry    Jones         London
# 3     Diane   Murphy  San Francisco    CA
# 4  Foon Yue    Tseng            NYC    NY

# %%
cur.execute('''select *
                from employees e
                join offices o on e.officeCode = o.officeCode
                order by firstName, lastName
                ''')
df = pd.DataFrame(cur.fetchall())
df.columns = [i[0]for i in cur.description]
df.head()
# Out:
#   employeeNumber lastName firstName extension                         email  \
# 0           1611   Fixter      Andy      x101  afixter@classicmodelcars.com
# 1           1143      Bow   Anthony     x5428     abow@classicmodelcars.com
# 2           1504    Jones     Barry      x102   bjones@classicmodelcars.com
# 3           1002   Murphy     Diane     x5800  dmurphy@classicmodelcars.com
# 4           1286    Tseng  Foon Yue     x2248   ftseng@classicmodelcars.com
#
#   officeCode reportsTo            jobTitle officeCode           city  \
# 0          6      1088           Sales Rep          6         Sydney
# 1          1      1056  Sales Manager (NA)          1  San Francisco
# 2          7      1102           Sales Rep          7         London
# 3          1                     President          1  San Francisco
# 4          3      1143           Sales Rep          3            NYC
#
#               phone           addressLine1 addressLine2 state    country  \
# ...

# %% [markdown]
# ## Customers and their Orders (a One-to-Many join)
#
# Return a list of all of the customers. For each customer return a record for each of their order numbers, order dates and statuses.

# %%
# Your code here
cur.execute('''select customerName, o.orderNumber, o.orderDate, o.status
                from customers c
                join orders o on c.customerNumber = o.customerNumber
                ''')
df = pd.DataFrame(cur.fetchall())
df.columns = [i[0]for i in cur.description]
df.head(50)
# Out:
#                     customerName orderNumber   orderDate      status
# 0              Atelier graphique       10123  2003-05-20     Shipped
# 1              Atelier graphique       10298  2004-09-27     Shipped
# 2              Atelier graphique       10345  2004-11-25     Shipped
# 3             Signal Gift Stores       10124  2003-05-21     Shipped
# 4             Signal Gift Stores       10278  2004-08-06     Shipped
# 5             Signal Gift Stores       10346  2004-11-29     Shipped
# 6     Australian Collectors, Co.       10120  2003-04-29     Shipped
# 7     Australian Collectors, Co.       10125  2003-05-21     Shipped
# 8     Australian Collectors, Co.       10223  2004-02-20     Shipped
# 9     Australian Collectors, Co.       10342  2004-11-24     Shipped
# 10    Australian Collectors, Co.       10347  2004-11-29     Shipped
# 11             La Rochelle Gifts       10275  2004-07-23     Shipped
# 12             La Rochelle Gifts       10315  2004-10-29     Shipped
# ...

# %% [markdown]
# ## Orders and their Order Details (another One-to-Many join)
#
# Return a list of orders. For each order return a record for each order detail within the order.

# %%
#this isn't needed....can answer question with basic select from orderdetails table

# Your code here
cur.execute('''select o.orderNumber, od.*
                from orders o
                join orderdetails od on o.orderNumber = od.orderNumber
                ''')
df = pd.DataFrame(cur.fetchall())
df.columns = [i[0]for i in cur.description]
df.head(50)
# Out:
#    orderNumber orderNumber productCode quantityOrdered priceEach  \
# 0        10100       10100    S18_1749              30    136.00
# 1        10100       10100    S18_2248              50     55.09
# 2        10100       10100    S18_4409              22     75.46
# 3        10100       10100    S24_3969              49     35.29
# 4        10101       10101    S18_2325              25    108.06
# 5        10101       10101    S18_2795              26    167.06
# 6        10101       10101    S24_1937              45     32.53
# 7        10101       10101    S24_2022              46     44.35
# 8        10102       10102    S18_1342              39     95.55
# 9        10102       10102    S18_1367              41     43.13
# 10       10103       10103    S10_1949              26    214.30
# 11       10103       10103    S10_4962              42    119.67
# 12       10103       10103    S12_1666              27    121.64
# ...

# %% [markdown]
# ## Orders, Order details and Product Details (a Many-to-Many Join)

# %% [markdown]
# Return a list of the orders with the the order information, and allthe product information for each product in the order.

# %%
# Your code here
cur.execute('''select o.orderNumber, od.*, p.*
                from orders o
                join orderdetails od on o.orderNumber = od.orderNumber
                join products p on od.productCode = p.productCode
                ''')
df = pd.DataFrame(cur.fetchall())
df.columns = [i[0]for i in cur.description]
df.head(50)
# Out:
#    orderNumber orderNumber productCode quantityOrdered priceEach  \
# 0        10100       10100    S18_1749              30    136.00
# 1        10100       10100    S18_2248              50     55.09
# 2        10100       10100    S18_4409              22     75.46
# 3        10100       10100    S24_3969              49     35.29
# 4        10101       10101    S18_2325              25    108.06
# 5        10101       10101    S18_2795              26    167.06
# 6        10101       10101    S24_1937              45     32.53
# 7        10101       10101    S24_2022              46     44.35
# 8        10102       10102    S18_1342              39     95.55
# 9        10102       10102    S18_1367              41     43.13
# 10       10103       10103    S10_1949              26    214.30
# 11       10103       10103    S10_4962              42    119.67
# 12       10103       10103    S12_1666              27    121.64
# ...

# %% [markdown]
# ## Summary

# %% [markdown]
# In this lab, you practiced your knowledge on One-to-Many and Many-to-many relationships!
